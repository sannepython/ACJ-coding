# %%
import pandas as pd

# %%
df = pd.read_csv('UDISE_2023-24_Table_2.1.csv')

# %%
df.columns = df.columns.str.replace(" ", "_")
df.columns = df.columns.str.replace("-", "_")
df.columns = df.columns.str.lower()
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:,.2f}'.format

# %%
df.head()
# Out:
#    sl._no.               india/state/ut  total_number_of___schools  \
# 0        1                        India                    1471891
# 1        2  Andaman and Nicobar Islands                        412
# 2        3               Andhra Pradesh                      61373
# 3        4            Arunachal Pradesh                       3490
# 4        5                        Assam                      56630
#
#    total_number_of___enrolments  total_number_of___teachers  \
# 0                     248045828                     9807600
# 1                         72119                        5750
# 2                       8741885                      338293
# 3                        323717                       24700
# 4                       6922533                      342199
#
#    percentage_share_of_schools_by_category___primary  \
# 0                                              50.00
# 1                                              50.70
# ...

# %%
df.tail(5)
# Out:
#     sl._no. india/state/ut  total_number_of___schools  \
# 32       33      Telangana                      42901
# 33       34        Tripura                       4923
# 34       35  Uttar Pradesh                     255087
# 35       36    Uttarakhand                      22551
# 36       37    West Bengal                      93945
#
#     total_number_of___enrolments  total_number_of___teachers  \
# 32                       7293644                      341460
# 33                        689408                       37661
# 34                      41662794                     1538479
# 35                       2372400                      130741
# 36                      18015525                      576557
#
#     percentage_share_of_schools_by_category___primary  \
# 32                                              47.90
# 33                                              50.20
# 34                                              52.30
# ...

# %%
df.shape
# Out:
# (37, 17)

# %%
df.columns
# Out:
# Index(['sl._no.', 'india/state/ut', 'total_number_of___schools',
#        'total_number_of___enrolments', 'total_number_of___teachers',
#        'percentage_share_of_schools_by_category___primary',
#        'percentage_share_of_schools_by_category___upper_primary',
#        'percentage_share_of_schools_by_category___secondary',
#        'percentage_share_of_schools_by_category___higher_secondary',
#        'percentage_share_of_enrolments_by_level____primary_',
#        'percentage_share_of_enrolments_by_level____upper_primary_',
#        'percentage_share_of_enrolments_by_level___secondary',
#        'percentage_share_of_enrolments_by_level___higher_secondary',
#        'percentage_share_of_teachers_by_school_category___primary',
#        'percentage_share_of_teachers_by_school_category___upper_primary',
#        'percentage_share_of_teachers_by_school_category___secondary',
#        'percentage_share_of_teachers_by_school_category___higher_secondary'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 17 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   sl._no.                                                             37 non-null     int64
#  1   india/state/ut                                                      37 non-null     str
#  2   total_number_of___schools                                           37 non-null     int64
#  3   total_number_of___enrolments                                        37 non-null     int64
#  4   total_number_of___teachers                                          37 non-null     int64
#  5   percentage_share_of_schools_by_category___primary                   37 non-null     float64
#  6   percentage_share_of_schools_by_category___upper_primary             37 non-null     float64
# ...

# %%
df.sort_values(by=['total_number_of___schools', 'total_number_of___teachers'], ascending=False).head(5)
# Out:
#     sl._no.  india/state/ut  total_number_of___schools  \
# 0         1           India                    1471891
# 34       35   Uttar Pradesh                     255087
# 20       21  Madhya Pradesh                     123412
# 21       22     Maharashtra                     108237
# 29       30       Rajasthan                     107757
#
#     total_number_of___enrolments  total_number_of___teachers  \
# 0                      248045828                     9807600
# 34                      41662794                     1538479
# 20                      15361543                      639525
# 21                      21375970                      738114
# 29                      16786065                      775745
#
#     percentage_share_of_schools_by_category___primary  \
# 0                                               50.00
# 34                                              52.30
# 20                                              49.40
# ...

# %%
df.describe()
# Out:
#        sl._no.  total_number_of___schools  total_number_of___enrolments  \
# count    37.00                      37.00                         37.00
# mean     19.00                  79,561.68                 13,407,882.59
# std      10.82                 240,765.83                 40,577,601.04
# min       1.00                      37.00                     12,591.00
# 25%      10.00                   3,490.00                    323,717.00
# 50%      19.00                  23,517.00                  5,599,742.00
# 75%      28.00                  61,373.00                 11,496,709.00
# max      37.00               1,471,891.00                248,045,828.00
#
#        total_number_of___teachers  \
# count                       37.00
# mean                   530,140.54
# std                  1,598,759.42
# min                        911.00
# 25%                     24,700.00
# 50%                    206,591.00
# 75%                    394,053.00
# max                  9,807,600.00
#
# ...

# %%
df["total_number_of___enrolments"]
# Out:
# 0     248045828
# 1         72119
# 2       8741885
# 3        323717
# 4       6922533
# 5      21348149
# 6        265706
# 7       5776548
# 8        141282
# 9       4506578
# 10       304735
# 11     11496709
# 12      5599742
# 13      1426412
# 14      2629949
# 15      7143255
# 16     11926303
# 17      6281704
# 18        56642
# 19        12591
# 20     15361543
# 21     21375970
# 22       647434
# 23      1052884
# 24       293763
# 25       412975
# 26      7756910
# 27       244828
# 28      5988681
# 29     16786065
# 30       121395
# 31     12993050
# 32      7293644
# 33       689408
# 34     41662794
# 35      2372400
# 36     18015525
# Name: total_number_of___enrolments, dtype: int64

# %%
df[[
    "total_number_of___enrolments",
    "total_number_of___teachers",
    "total_number_of___schools"
]]
# Out:
#     total_number_of___enrolments  total_number_of___teachers  \
# 0                      248045828                     9807600
# 1                          72119                        5750
# 2                        8741885                      338293
# 3                         323717                       24700
# 4                        6922533                      342199
# 5                       21348149                      657063
# 6                         265706                       10237
# 7                        5776548                      278798
# 8                         141282                        4995
# 9                        4506578                      160479
# 10                        304735                       14594
# 11                      11496709                      394053
# 12                       5599742                      250909
# 13                       1426412                      101131
# ...

# %%
df.sort_values(
    by="total_number_of___enrolments",
    ascending=False
)[["total_number_of___teachers", "total_number_of___schools"]].head(10)
# Out:
#     total_number_of___teachers  total_number_of___schools
# 0                      9807600                    1471891
# 34                     1538479                     255087
# 21                      738114                     108237
# 5                       657063                      94686
# 36                      576557                      93945
# 29                      775745                     107757
# 20                      639525                     123412
# 31                      550558                      58722
# 16                      433942                      75869
# 11                      394053                      53626

# %%
df.sort_values(
    by="total_number_of___enrolments",
    ascending=False
)[["percentage_share_of_schools_by_category___secondary", "percentage_share_of_schools_by_category___upper_primary"]].head(10)

# %%
df[df["india/state/ut"] == "Uttar_Pradesh"]

# %%
df[df["percentage_share_of_schools_by_category___secondary"] > 30][[
    "india/state/ut",
    "percentage_share_of_schools_by_category___upper_primary"
]]

# %%
df["percentage_share_of_schools_by_category___secondary"]
df["percentage_share_of_schools_by_category___secondary"] > 2
df[df["percentage_share_of_schools_by_category___secondary"] > 2]

# %%
df.query("total_number_of___schools > 2")

# %%
df["percentage_share_of_schools_by_category___secondary"].mean()

# %%
df["percentage_share_of_schools_by_category___secondary"].mean().round(2)

# %%
df["percentage_share_of_schools_by_category___secondary"].median()

# %%
df["percentage_share_of_schools_by_category___secondary"].min()

# %%
df["percentage_share_of_schools_by_category___secondary"].max()

# %%
df.total_number_of_enrolments_total.max()

# %%
df.isna().sum().sort_values(ascending=False)

# %%
df[df["total_number_of_schools_total"].isna()][[
    "percentage_share_of_schools_by_category___upper_primary",
    "percentage_share_of_schools_by_category_primary"
]]

# %%
df[[
    "india/state/ut",
    "total_number_of___schools",
    "total_number_of___teachers"
]].sort_values(
    "total_number_of___schools",
    ascending=False
).head(10)

# %%
df["total_number_of___schools"]
df["total_number_of___schools"]>2
df[df["total_number_of___schools"]>2]

# %%
df["total_number_of___schools"].mean()

# %%
df["total_number_of___teachers"].mean().round(2)

# %%
df["total_number_of___teachers"].median()

# %%
df["total_number_of___teachers"].min()

# %%
df["total_number_of___teachers"].max()

# %%
df.percentage_share_of_schools_by_category_primary.max()

# %%
df.isna().sum().sort_values(ascending=False)

# %%
df[[
    "india/state/ut",
    "total_number_of___enrolments",
    "total_number_of___teachers"
]].sort_values(
    "total_number_of___enrolments",
    ascending=False
).head(10)
